# %% [markdown]
# <a href="https://colab.research.google.com/github/raykipa/python_projects/blob/master/city_records_DSI_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/drive/My Drive/Recent_Contract_Awards.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (12,13,14,15,27,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#      RequestID   StartDate     EndDate  ... EventCity EventStateCode EventZipCode
# 0  20100628021  07/06/2010  07/06/2010  ...       NaN            NaN          NaN
# 1  20130214010  02/22/2013  02/22/2013  ...       NaN            NaN          NaN
# 2  20090911004  09/18/2009  09/18/2009  ...       NaN            NaN          NaN
# 3  20130415019  04/22/2013  04/22/2013  ...       NaN            NaN          NaN
# 4  20110623031  06/24/2011  06/24/2011  ...       NaN            NaN          NaN
#
# [5 rows x 37 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35544 entries, 0 to 35543
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   RequestID                     35544 non-null  int64
#  1   StartDate                     35544 non-null  object
#  2   EndDate                       35544 non-null  object
#  3   AgencyName                    35544 non-null  object
#  4   TypeOfNoticeDescription       35544 non-null  object
#  5   CategoryDescription           35544 non-null  object
#  6   ShortTitle                    35544 non-null  object
#  7   SelectionMethodDescription    35544 non-null  object
#  8   SectionName                   35544 non-null  object
#  9   SpecialCaseReasonDescription  12616 non-null  object
#  10  PIN                           35537 non-null  object
#  11  DueDate                       0 non-null      float64
# ...

# %%
data["StartDate"]
# Out:
# 0        07/06/2010
# 1        02/22/2013
# 2        09/18/2009
# 3        04/22/2013
# 4        06/24/2011
#             ...
# 35539    10/14/2014
# 35540    12/09/2010
# 35541    12/27/2013
# 35542    12/23/2015
# 35543    01/15/2014
# Name: StartDate, Length: 35544, dtype: object

# %%
newdata= in_range_data = data[data["StartDate"].isin(pd.date_range("01/01/2010", "12/31/2019"))]

# %%
data["StartDate"].value_counts()
# Out:
# 10/03/2003    68
# 06/30/2017    57
# 10/15/2019    50
# 10/09/2003    49
# 06/10/2004    48
#               ..
# 06/16/2008     1
# 08/02/2005     1
# 02/13/2018     1
# 03/09/2011     1
# 09/15/2014     1
# Name: StartDate, Length: 4292, dtype: int64

# %%
data["ContractAmount"].value_counts()
# Out:
# -1.00          1403
#  100000.00      463
#  150000.00      240
#  1000000.00     201
#  4000000.00     173
#                ...
#  175580.00        1
#  141625.00        1
#  763110.00        1
#  128157.50        1
#  204675.75        1
# Name: ContractAmount, Length: 25133, dtype: int64

# %%
data_contract_above_zero = data[ data["ContractAmount"] < 0 ]

# %%
new_data1 = data.drop(data_contract_above_zero.index, axis=0)

# %%
new_data1.head()
# Out:
#      RequestID   StartDate     EndDate  ... EventCity EventStateCode EventZipCode
# 0  20100628021  07/06/2010  07/06/2010  ...       NaN            NaN          NaN
# 1  20130214010  02/22/2013  02/22/2013  ...       NaN            NaN          NaN
# 2  20090911004  09/18/2009  09/18/2009  ...       NaN            NaN          NaN
# 3  20130415019  04/22/2013  04/22/2013  ...       NaN            NaN          NaN
# 4  20110623031  06/24/2011  06/24/2011  ...       NaN            NaN          NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# dropping the NaN values

# %%
new_data2=new_data1.dropna(subset=["ContractAmount"])

# %%
new_data2.head()
# Out:
#      RequestID   StartDate     EndDate  ... EventCity EventStateCode EventZipCode
# 0  20100628021  07/06/2010  07/06/2010  ...       NaN            NaN          NaN
# 1  20130214010  02/22/2013  02/22/2013  ...       NaN            NaN          NaN
# 3  20130415019  04/22/2013  04/22/2013  ...       NaN            NaN          NaN
# 4  20110623031  06/24/2011  06/24/2011  ...       NaN            NaN          NaN
# 5  20130621002  06/27/2013  06/27/2013  ...       NaN            NaN          NaN
#
# [5 rows x 37 columns]

# %%
new_data3= in_range_new_data2 = new_data2[new_data2["StartDate"].isin(pd.date_range("01/01/2010", "12/31/2019"))]

# %%
new_data3=new_data2['StartDate'] = pd.to_datetime(new_data2['StartDate'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Selecting a  range of rows of values from 2010 to 2019

# %%
mask = (new_data2['StartDate'] > '01/01/2010') & (new_data2['StartDate'] <= '12/31/2010')

# %%
new_data2.loc[mask]
# Out:
#          RequestID  StartDate  ... EventStateCode EventZipCode
# 0      20100628021 2010-07-06  ...            NaN          NaN
# 24     20100308010 2010-03-12  ...            NaN          NaN
# 44     20101116040 2010-11-22  ...            NaN          NaN
# 186    20100811008 2010-08-18  ...            NaN          NaN
# 224    20100518020 2010-05-26  ...            NaN          NaN
# ...            ...        ...  ...            ...          ...
# 35482  20101130011 2010-12-07  ...            NaN          NaN
# 35492  20100709016 2010-07-16  ...            NaN          NaN
# 35511  20100520028 2010-05-27  ...            NaN          NaN
# 35529  20100812005 2010-08-19  ...            NaN          NaN
# 35540  20101202005 2010-12-09  ...            NaN          NaN
#
# [1371 rows x 37 columns]

# %%
new_data3=new_data2.loc[mask]

# %%
new_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1371 entries, 0 to 35540
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   RequestID                     1371 non-null   int64
#  1   StartDate                     1371 non-null   datetime64[ns]
#  2   EndDate                       1371 non-null   object
#  3   AgencyName                    1371 non-null   object
#  4   TypeOfNoticeDescription       1371 non-null   object
#  5   CategoryDescription           1371 non-null   object
#  6   ShortTitle                    1371 non-null   object
#  7   SelectionMethodDescription    1371 non-null   object
#  8   SectionName                   1371 non-null   object
#  9   SpecialCaseReasonDescription  476 non-null    object
#  10  PIN                           1371 non-null   object
#  11  DueDate                       0 non-null      float64
# ...

# %% [markdown]
# Creating mean of top 5 vendors

# %%
new_data3['AgencyName_mean'] = new_data3.AgencyName.map(new_data3.groupby(['AgencyName']).ContractAmount.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#agency_data= new_data3

# %%
#agency_data.set_index('AgencyName', inplace=True)

# %%
citywide = agency_data.loc['Citywide Administrative Services', 'ContractAmount']
health = agency_data.loc['Health and Mental Hygiene', 'ContractAmount']
design = agency_data.loc['Design and Construction', 'ContractAmount']
homeless = agency_data.loc['Homeless Services', 'ContractAmount']
social = agency_data.loc['Dept Of Social Svcs/Human Resources Administration', 'ContractAmount']

# %%
print(citywide.mean())
print(health.mean())
print(design.mean())
print(homeless.mean())
print(social.mean())
# Out:
# 1627119.4986344525
# 4044836.722920354
# 5388700.0428057555
# 5203227.742190476
# 14908618.654563105

# %%
vendor_mean_list = [1627119.4986344525, 4044836.722920354, 5388700.0428057555, 5203227.742190476, 14908618.654563105]

# %%
import heapq
heapq.nlargest(2, vendor_mean_list)
# Out:
# [14908618.654563105, 5388700.0428057555]

# %%
#Ration of highest number to second highest number
print(14908618.654563105/5388700.0428057555)
# Out:
# 2.766644744768643

# %%
new_data3.head()
# Out:
#                                                       RequestID  ... AgencyName_mean
# AgencyName                                                       ...
# Transportation                                      20100628021  ...    7.560111e+04
# Transportation                                      20100308010  ...    7.560111e+04
# Transportation                                      20101116040  ...    7.560111e+04
# Dept Of Social Svcs/Human Resources Administration  20100811008  ...    1.490862e+07
# Dept Of Social Svcs/Human Resources Administration  20100518020  ...    1.490862e+07
#
# [5 rows x 37 columns]

# %%
#Contract Amount per vendor
mask1 = (new_data3['AgencyName'])

# %%
new_data3.head()

# %%
groupby_AgencyName = new_data3['ContractAmount'].groupby(new_data3['AgencyName'])
groupby_AgencyName

# %%
new_data3.groupby(['AgencyName']).agg({"ContractAmount":"mean"})

# %% [markdown]
# Consider only procurements made by the Citywide Administrative Services agency and compute the sum contract amount awarded to each unique vendor. What proportion of the total number of contracts in the data set were awarded to the top 50 vendors?

# %%
citywide_data=new_data3[new_data3['AgencyName'] == 'Citywide Administrative Services']

# %%
groupby_vendorName = citywide_data['ContractAmount'].groupby(citywide_data['VendorName'])
groupby_vendorName

# %%
vendor_data=citywide_data.groupby(['VendorName']).agg({"ContractAmount":"sum"})

# %%
vendor_data.ContractAmount.sort_values(ascending= False)

# %%
vendor_data_ascending = vendor_data.ContractAmount.sort_values(ascending= False)

# %%
vendor_data_ascending.head(50)

# %% [markdown]
# Do agencies publish procurement notices uniformly throughout the week? As an example, consider the agency of Parks and Recreation. For this agency, compute the weekday for which each notice was published, and perform a Chi-squared test on the null hypothesis that each weekday occurs equally often. Report the value of the test statistic.

# %%
parks_recreation_data=new_data3[new_data3['AgencyName'] == 'Parks and Recreation']

# %%
parks_recreation_data.info()

# %%
#parks_recreation_data['StartDate'] = pd.to_datetime(parks_recreation_data['StartDate'])

mask2 = parks_recreation_data['day_of_week'] = parks_recreation_data['StartDate'].dt.day_name()
parks_recreation_data.loc[mask2]

# %%
weekday = parks_recreation_data['StartDate'].dt.day_name()

# %%
parks_recreation_data['weekday'] = weekday
parks_recreation_data

# %%
table = pd.crosstab(cyl,am)

# %%
from sipy.stat import chi2.contigency
chi2, p, dof, expected = chi2_expected = chi2_contigency(table.values)

# %% [markdown]
# For this question, consider only contracts with in the categories of Construction Related Services and Construction/Construction Services. The ShortTitle field contains a description of the procured goods/services for each contract. Compute the sum contract amount for contracts whose ShortTitle refer to 'CENTRAL PARK' and for those which refer to 'WASHINGTON SQUARE PARK'. What is the ratio of total construction and contruction-related expenditure for the Central Park contracts compared to the Washington Square Park contracts? Note: you should ensure that 'PARK' appears on its own and not as the beginning of another word

# %%
new_data3['CategoryDescription'].value_counts()
# Out:
# Goods                                   437
# Human Services/Client Services          396
# Services (other than human services)    217
# Construction/Construction Services      186
# Construction Related Services            83
# Goods and Services                       52
# Name: CategoryDescription, dtype: int64

# %%
construction_data=new_data3[new_data3['CategoryDescription'] == 'Construction/Construction Services' && 'Construction Related Services']

# %%
central_park_data=construction_data[construction_data['ShortTitle'] == 'Construction/Construction Services']

# %%
groupby_shortitle = construction_data['ContractAmount'].groupby(construction_data['VendorName'])
groupby_shortitle

# %%
construction_data['ShortTitle']
# Out:
# 815      HWS2010Q, RESIDENT ENGINEERING INSPECTION SERV...
# 969                                        ELECTRICAL WORK
# 1160                            ELECTRICAL UPGRADE PROJECT
# 1474     RESIDENT ENGINEERING INSPECTION SERVICES FOR T...
# 1653     EMERGENCY DEMOLITION OF ONE (1) BUILDING - REA...
#                                ...
# 34802    CONSTRUCTION OF SANITARY AND STORM SEWERS IN 1...
# 34805    CONSTRUCTION AND RECONSTRUCTION OF PLAYGROUNDS...
# 35143    ENGINSP3, RENEWAL OF REQUIREMENTS CONTRACT FOR...
# 35183    INSTALLATION OF FIVE (5) RECREATION LIGHT POLE...
# 35422          SCHOOL SAFETY IMPROVEMENT, PHASE 3 CITYWIDE
# Name: ShortTitle, Length: 186, dtype: object

# %%
construction_data[construction_data.ShortTitle == 'WASHINGTON']
# Out:
# Empty DataFrame
# Columns: [RequestID, StartDate, EndDate, AgencyName, TypeOfNoticeDescription, CategoryDescription, ShortTitle, SelectionMethodDescription, SectionName, SpecialCaseReasonDescription, PIN, DueDate, AddressToRequest, ContactName, ContactPhone, Email, ContractAmount, ContactFax, AdditionalDescription1, AdditionalDesctription2, AdditionalDescription3, OtherInfo1, OtherInfo2, OtherInfo3, VendorName, VendorAddress, Printout1, Printout2, Printout3, DocumentLinks, EventDate, EventBuildingName, EventStreetAddress1, EventStreetAddress2, EventCity, EventStateCode, EventZipCode]
# Index: []
